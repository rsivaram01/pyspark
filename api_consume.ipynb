# %% [markdown]
# step 1 ==> i'll the api get the data
# step 2 ==> we need faltten
# step 3 ==> write the data into table

# %%
import requests
import pandas as pd

url = "https://jsonplaceholder.typicode.com/posts"
resp = requests.get(url, timeout=10)
resp.raise_for_status()
data = resp.json()  # list of dicts
df = pd.DataFrame(data)

spark_df = spark.createDataFrame(df)

spark_df.write.mode("overwrite").saveAsTable("sample_cat.flights.apiTable")
